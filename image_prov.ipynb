# %% [markdown]
# <a href="https://colab.research.google.com/github/Josue-Praciano/verbos-psicol-gicos-separabilidade-linear/blob/main/image_prov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install prov

from prov.dot import prov_to_dot
from prov.model import ProvDocument
from pathlib import Path

# Define o caminho para o seu arquivo PROV JSON
prov_json_file = Path('/content/pipeline_provenance.json')

# Verifica se o arquivo existe
if prov_json_file.exists():
    # Lê o conteúdo do arquivo JSON
    with open(prov_json_file, 'r', encoding='utf-8') as f:
        json_data = f.read()

    # Deserializa o JSON para um objeto ProvDocument
    d1 = ProvDocument.deserialize(content=json_data, format='json')

    # Converte o documento de proveniência para um objeto Graphviz Dot
    dot = prov_to_dot(d1)

    # Define o caminho de saída para a imagem PNG
    output_png_path = 'sample_data/pipeline_provenance.png'

    # Salva o gráfico como uma imagem PNG
    dot.write_png(output_png_path)
    print(f"Imagem de proveniência salva em: {output_png_path}")
else:
    print(f"Erro: O arquivo PROV JSON não foi encontrado em {prov_json_file}.")
    print("Por favor, execute a função `generate_complete_pipeline_provenance()` ou verifique o caminho do arquivo.")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.3/587.3 kB 27.1 MB/s eta 0:00:00
# ...
# /tmp/ipykernel_2191/3113467596.py:3: DeprecationWarning: In prov 3.0, graphical export (prov.dot) will require the optional "dot" extra; install "prov[dot]" to keep using it after upgrading. See https://github.com/trungdong/prov/blob/master/ROADMAP.md
#   from prov.dot import prov_to_dot
# /usr/local/lib/python3.12/dist-packages/prov/dot.py:451: FutureWarning: prov 3.0 will change unified() to merge records per the W3C PROV-CONSTRAINTS rules; records sharing an identifier but having conflicting formal attributes will then raise an error instead of having their attributes silently unioned. See https://github.com/trungdong/prov/blob/master/ROADMAP.md
#   unified = bundle.unified()
# Imagem de proveniência salva em: sample_data/pipeline_provenance.png
